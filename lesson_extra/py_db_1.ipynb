# %%
import sqlalchemy

# %%
# создаем engine
engine = sqlalchemy.create_engine('postgresql://postgres:admin@localhost:5432/postgres')
engine
# Out:
# Engine(postgresql://postgres:***@localhost:5432/postgres)

# %%
# посмотрим, какие таблицы есть
print(engine.table_names())
# Out:
# ['payment', 'film', 'actor', 'address', 'category', 'city', 'country', 'customer', 'film_actor', 'film_category', 'inventory', 'language', 'rental', 'staff', 'store', 'payment_p2017_01', 'payment_p2017_02', 'payment_p2017_03', 'payment_p2017_04', 'payment_p2017_05', 'payment_p2017_06']

# %%
# установим со единение
connection = engine.connect()

# %% [markdown]
# SELECT

# %%
# выберем все поля из таблицы film
sel = connection.execute("""SELECT * FROM film;
""").fetchone()
print(sel)
# Out:
# (1, 'ACADEMY DINOSAUR', 'A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies', 2006, 1, None, 6, Decimal('0.99'), 86, Decimal('20.99'), 'PG', datetime.datetime(2017, 9, 10, 17, 46, 3, 905795, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), ['Deleted Scenes', 'Behind the Scenes'], "'academi':1 'battl':15 'canadian':20 'dinosaur':2 'drama':5 'epic':4 'feminist':8 'mad':11 'must':14 'rocki':21 'scientist':12 'teacher':17")

# %%
type(sel)
# Out:
# sqlalchemy.engine.result.RowProxy

# %%
# выберем столбец title таблицы film
connection.execute("""SELECT title FROM film;
""").fetchmany(10)
# Out:
# [('ACADEMY DINOSAUR',),
#  ('ACE GOLDFINGER',),
#  ('ADAPTATION HOLES',),
#  ('AFFAIR PREJUDICE',),
#  ('AFRICAN EGG',),
#  ('AGENT TRUMAN',),
#  ('AIRPLANE SIERRA',),
#  ('AIRPORT POLLOCK',),
#  ('ALABAMA DEVIL',),
#  ('ALADDIN CALENDAR',)]

# %%
import pandas as pd

# %%
# выберем 2 столбца из таблицы film
connection.execute("""SELECT title, release_year FROM film;
""").fetchmany(10)
# Out:
# [('ACADEMY DINOSAUR', 2006),
#  ('ACE GOLDFINGER', 2006),
#  ('ADAPTATION HOLES', 2006),
#  ('AFFAIR PREJUDICE', 2006),
#  ('AFRICAN EGG', 2006),
#  ('AGENT TRUMAN', 2006),
#  ('AIRPLANE SIERRA', 2006),
#  ('AIRPORT POLLOCK', 2006),
#  ('ALABAMA DEVIL', 2006),
#  ('ALADDIN CALENDAR', 2006)]

# %%
# Практика. Напишите запрос, который отберет имена и фамилии актеров из соотвествующей таблицы
connection.execute("""select first_name, last_name from actor
""").fetchmany(10)
# Out:
# [('PENELOPE', 'GUINESS'),
#  ('NICK', 'WAHLBERG'),
#  ('ED', 'CHASE'),
#  ('JENNIFER', 'DAVIS'),
#  ('JOHNNY', 'LOLLOBRIGIDA'),
#  ('BETTE', 'NICHOLSON'),
#  ('GRACE', 'MOSTEL'),
#  ('MATTHEW', 'JOHANSSON'),
#  ('JOE', 'SWANK'),
#  ('CHRISTIAN', 'GABLE')]

# %%
connection.execute("""SELECT first_name, last_name FROM actor;
""").fetchmany(10)
# Out:
# [('PENELOPE', 'GUINESS'),
#  ('NICK', 'WAHLBERG'),
#  ('ED', 'CHASE'),
#  ('JENNIFER', 'DAVIS'),
#  ('JOHNNY', 'LOLLOBRIGIDA'),
#  ('BETTE', 'NICHOLSON'),
#  ('GRACE', 'MOSTEL'),
#  ('MATTHEW', 'JOHANSSON'),
#  ('JOE', 'SWANK'),
#  ('CHRISTIAN', 'GABLE')]

# %%
# как работает DISTINCT
# выведем столбец rating из film
res = connection.execute("""SELECT rating FROM film;
""").fetchmany(10)
res
# Out:
# [('PG',),
#  ('G',),
#  ('NC-17',),
#  ('G',),
#  ('G',),
#  ('PG',),
#  ('PG-13',),
#  ('R',),
#  ('PG-13',),
#  ('NC-17',)]

# %%
# найдем, какие рейтинги бывают
connection.execute("""SELECT DISTINCT rating FROM film;
""").fetchall()
# Out:
# [('PG-13',), ('G',), ('NC-17',), ('R',), ('PG',)]

# %% [markdown]
# Примеры с арифметикой

# %%
# переведем цены в условные рубли
connection.execute("""SELECT amount * 70 FROM payment;
""").fetchmany(10)
# Out:
# [(Decimal('139.30'),),
#  (Decimal('69.30'),),
#  (Decimal('489.30'),),
#  (Decimal('69.30'),),
#  (Decimal('349.30'),),
#  (Decimal('209.30'),),
#  (Decimal('139.30'),),
#  (Decimal('349.30'),),
#  (Decimal('629.30'),),
#  (Decimal('69.30'),)]

# %%
# узнаем время аренды по позициям
connection.execute("""SELECT rental_date - return_date FROM rental;
""").fetchmany(10)
# Out:
# [(datetime.timedelta(days=-4, seconds=11640),),
#  (datetime.timedelta(days=-8, seconds=3060),),
#  (datetime.timedelta(days=-10, seconds=76860),),
#  (datetime.timedelta(days=-9, seconds=66720),),
#  (datetime.timedelta(days=-3, seconds=77760),),
#  (datetime.timedelta(days=-5, seconds=9420),),
#  (datetime.timedelta(days=-4, seconds=86280),),
#  (datetime.timedelta(days=-4, seconds=85080),),
#  (datetime.timedelta(days=-7, seconds=4680),),
#  (datetime.timedelta(days=-9, seconds=11580),)]

# %% [markdown]
# WHERE

# %%
# найдем фильмы, вышедшие после 2000
connection.execute("""SELECT title, release_year FROM film
WHERE release_year >= 2000;
""").fetchall()
# Out:
# [('ACADEMY DINOSAUR', 2006),
#  ('ACE GOLDFINGER', 2006),
#  ('ADAPTATION HOLES', 2006),
#  ('AFFAIR PREJUDICE', 2006),
#  ('AFRICAN EGG', 2006),
#  ('AGENT TRUMAN', 2006),
#  ('AIRPLANE SIERRA', 2006),
#  ('AIRPORT POLLOCK', 2006),
#  ('ALABAMA DEVIL', 2006),
#  ('ALADDIN CALENDAR', 2006),
#  ('ALAMO VIDEOTAPE', 2006),
#  ('ALASKA PHANTOM', 2006),
#  ('DATE SPEED', 2006),
#  ('ALI FOREVER', 2006),
#  ('ALICE FANTASIA', 2006),
#  ('ALIEN CENTER', 2006),
#  ('ALLEY EVOLUTION', 2006),
#  ('ALONE TRIP', 2006),
#  ('ALTER VICTORY', 2006),
#  ('AMADEUS HOLY', 2006),
#  ('AMELIE HELLFIGHTERS', 2006),
#  ('AMERICAN CIRCUS', 2006),
#  ('AMISTAD MIDSUMMER', 2006),
#  ('ANACONDA CONFESSIONS', 2006),
#  ('ANALYZE HOOSIERS', 2006),
#  ('ANGELS LIFE', 2006),
#  ('ANNIE IDENTITY', 2006),
#  ('ANONYMOUS HUMAN', 2006),
#  ('ANTHEM LUKE', 2006),
#  ('ANTITRUST TOMATOES', 2006),
#  ('ANYTHING SAVANNAH', 2006),
#  ('APACHE DIVINE', 2006),
#  ('APOCALYPSE FLAMINGOS', 2006),
#  ('APOLLO TEEN', 2006),
# ...

# %%
# найдем сотрудников, которые сейчас работают
connection.execute("""SELECT first_name, last_name, +active FROM staff
WHERE active = true;
""").fetchmany(10)
# Out:
# [('Mike', 'Hillyer', True), ('Jon', 'Stephens', True)]

# %%
# критерий не обязательно должен входить в выборку
connection.execute("""SELECT first_name, last_name FROM staff
WHERE active = true;
""").fetchmany(10)
# Out:
# [('Mike', 'Hillyer'), ('Jon', 'Stephens')]

# %%
# Практика. найдем ID, имена, фамилии актеров, которых зовут JOE
connection.execute("""SELECT actor_id, first_name, last_name FROM actor WHERE first_name = 'JOE';
""").fetchall()
# Out:
# [(9, 'JOE', 'SWANK')]

# %%
# найдем всех сотрудников, которые работают не во втором магазине
connection.execute("""SELECT first_name, last_name FROM staff
WHERE store_id != 2;
""").fetchmany(10)
# Out:
# [('Mike', 'Hillyer')]

# %%
# найдем только работающих сотрудников из всех магазинов, кроме 1
connection.execute("""SELECT first_name, last_name FROM staff
WHERE active = true AND NOT store_id = 1;
""").fetchmany(10)
# Out:
# [('Jon', 'Stephens')]

# %%
# найдем фильмы, цена проката которых меньше 0.99, а цена возмещения меньше 9.99
connection.execute("""SELECT title, rental_rate, replacement_cost FROM film
WHERE rental_rate <= 0.99 AND replacement_cost <= 9.99;
""").fetchmany(10)
# Out:
# [('ANACONDA CONFESSIONS', Decimal('0.99'), Decimal('9.99')),
#  ('DELIVERANCE MULHOLLAND', Decimal('0.99'), Decimal('9.99')),
#  ('ENCINO ELF', Decimal('0.99'), Decimal('9.99')),
#  ('FACTORY DRAGON', Decimal('0.99'), Decimal('9.99')),
#  ('GANDHI KWAI', Decimal('0.99'), Decimal('9.99')),
#  ('NEWTON LABYRINTH', Decimal('0.99'), Decimal('9.99')),
#  ('NOTORIOUS REUNION', Decimal('0.99'), Decimal('9.99')),
#  ('PAPI NECKLACE', Decimal('0.99'), Decimal('9.99')),
#  ('ROXANNE REBEL', Decimal('0.99'), Decimal('9.99')),
#  ('SUN CONFESSIONS', Decimal('0.99'), Decimal('9.99'))]

# %%
# найдем фильмы аналогичные предыдущему примеру или продолжительностью меньше 30 минут
connection.execute("""SELECT title, length, rental_rate, replacement_cost FROM film
WHERE length <= 30 OR rental_rate <= 0.99 AND replacement_cost <= 9.99;
""").fetchmany(10)
# Out:
# [('ANACONDA CONFESSIONS', 92, Decimal('0.99'), Decimal('9.99')),
#  ('DELIVERANCE MULHOLLAND', 100, Decimal('0.99'), Decimal('9.99')),
#  ('ENCINO ELF', 143, Decimal('0.99'), Decimal('9.99')),
#  ('FACTORY DRAGON', 144, Decimal('0.99'), Decimal('9.99')),
#  ('GANDHI KWAI', 86, Decimal('0.99'), Decimal('9.99')),
#  ('NEWTON LABYRINTH', 75, Decimal('0.99'), Decimal('9.99')),
#  ('NOTORIOUS REUNION', 128, Decimal('0.99'), Decimal('9.99')),
#  ('PAPI NECKLACE', 128, Decimal('0.99'), Decimal('9.99')),
#  ('ROXANNE REBEL', 171, Decimal('0.99'), Decimal('9.99')),
#  ('SUN CONFESSIONS', 141, Decimal('0.99'), Decimal('9.99'))]

# %% [markdown]
# IN / NOT IN

# %%
# найдем фильмы с рейтингом R, NC-17
connection.execute("""SELECT title, description, rating FROM film
WHERE rating IN ('R', 'NC-17');
""").fetchmany(10)
# Out:
# [('ADAPTATION HOLES', 'A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory', 'NC-17'),
#  ('AIRPORT POLLOCK', 'A Epic Tale of a Moose And a Girl who must Confront a Monkey in Ancient India', 'R'),
#  ('ALADDIN CALENDAR', 'A Action-Packed Tale of a Man And a Lumberjack who must Reach a Feminist in Ancient China', 'NC-17'),
#  ('DATE SPEED', 'A Touching Saga of a Composer And a Moose who must Discover a Dentist in A MySQL Convention', 'R'),
#  ('ALICE FANTASIA', 'A Emotional Drama of a A Shark And a Database Administrator who must Vanquish a Pioneer in Soviet Georgia', 'NC-17'),
#  ('ALIEN CENTER', 'A Brilliant Drama of a Cat And a Mad Scientist who must Battle a Feminist in A MySQL Convention', 'NC-17'),
#  ('ALLEY EVOLUTION', 'A Fast-Paced Drama of a Robot And a Composer who must Battle a Astronaut in New Orleans', 'NC-17'),
# ...

# %%
# найдем недетские фильмы
connection.execute("""SELECT title, description, rating FROM film
WHERE rating NOT IN ('G', 'PG');
""").fetchmany(10)
# Out:
# [('ADAPTATION HOLES', 'A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory', 'NC-17'),
#  ('AIRPLANE SIERRA', 'A Touching Saga of a Hunter And a Butler who must Discover a Butler in A Jet Boat', 'PG-13'),
#  ('AIRPORT POLLOCK', 'A Epic Tale of a Moose And a Girl who must Confront a Monkey in Ancient India', 'R'),
#  ('ALABAMA DEVIL', 'A Thoughtful Panorama of a Database Administrator And a Mad Scientist who must Outgun a Mad Scientist in A Jet Boat', 'PG-13'),
#  ('ALADDIN CALENDAR', 'A Action-Packed Tale of a Man And a Lumberjack who must Reach a Feminist in Ancient China', 'NC-17'),
#  ('DATE SPEED', 'A Touching Saga of a Composer And a Moose who must Discover a Dentist in A MySQL Convention', 'R'),
#  ('ALICE FANTASIA', 'A Emotional Drama of a A Shark And a Database Administrator who must Vanquish a Pioneer in Soviet Georgia', 'NC-17'),
# ...

# %% [markdown]
# BETWEEN

# %%
connection.execute("""SELECT title, rental_rate FROM film
WHERE rental_rate BETWEEN 0.99 AND 3;
""").fetchall()
# Out:
# [('ACADEMY DINOSAUR', Decimal('0.99')),
#  ('ADAPTATION HOLES', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', Decimal('2.99')),
#  ('AFRICAN EGG', Decimal('2.99')),
#  ('AGENT TRUMAN', Decimal('2.99')),
#  ('ALABAMA DEVIL', Decimal('2.99')),
#  ('ALAMO VIDEOTAPE', Decimal('0.99')),
#  ('ALASKA PHANTOM', Decimal('0.99')),
#  ('DATE SPEED', Decimal('0.99')),
#  ('ALICE FANTASIA', Decimal('0.99')),
#  ('ALIEN CENTER', Decimal('2.99')),
#  ('ALLEY EVOLUTION', Decimal('2.99')),
#  ('ALONE TRIP', Decimal('0.99')),
#  ('ALTER VICTORY', Decimal('0.99')),
#  ('AMADEUS HOLY', Decimal('0.99')),
#  ('AMISTAD MIDSUMMER', Decimal('2.99')),
#  ('ANACONDA CONFESSIONS', Decimal('0.99')),
#  ('ANALYZE HOOSIERS', Decimal('2.99')),
#  ('ANGELS LIFE', Decimal('2.99')),
#  ('ANNIE IDENTITY', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', Decimal('0.99')),
#  ('ANTITRUST TOMATOES', Decimal('2.99')),
#  ('ANYTHING SAVANNAH', Decimal('2.99')),
#  ('APOLLO TEEN', Decimal('2.99')),
#  ('ARABIA DOGMA', Decimal('0.99')),
# ...

# %% [markdown]
# LIKE

# %%
# Найдем фильм, в описании которого есть Scientist
connection.execute("""SELECT title, description FROM film
WHERE description LIKE '%%Scientist%%';
""").fetchall()
# Out:
# [('ACADEMY DINOSAUR', 'A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies'),
#  ('ALABAMA DEVIL', 'A Thoughtful Panorama of a Database Administrator And a Mad Scientist who must Outgun a Mad Scientist in A Jet Boat'),
#  ('ALIEN CENTER', 'A Brilliant Drama of a Cat And a Mad Scientist who must Battle a Feminist in A MySQL Convention'),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 'A Action-Packed Reflection of a Pastry Chef And a Composer who must Discover a Mad Scientist in The First Manned Space Station'),
#  ('ARIZONA BANG', 'A Brilliant Panorama of a Mad Scientist And a Mad Cow who must Meet a Pioneer in A Monastery'),
#  ('ATTACKS HATE', 'A Fast-Paced Panorama of a Technical Writer And a Mad Scientist who must Find a Feminist in An Abandoned Mine Shaft'),
#  ('BACKLASH UNDEFEATED', 'A Stunning Character Study of a Mad Scientist And a Mad Cow who must Kill a Car in A Monastery'),
# ...

# %%
# Практика. найдем ID, имена, фамилии актеров, фамилия которых содержит GEN
connection.execute("""SELECT actor_id, first_name, last_name FROM actor WHERE last_name LIKE '%%GEN%%'
""").fetchmany(10)
# Out:
# [(14, 'VIVIEN', 'BERGEN'),
#  (41, 'JODIE', 'DEGENERES'),
#  (107, 'GINA', 'DEGENERES'),
#  (166, 'NICK', 'DEGENERES')]

# %% [markdown]
# ORDER BY

# %%
# Отсортируем фильмы по цене проката
connection.execute("""SELECT title, rental_rate FROM film
ORDER BY rental_rate;
""").fetchall()
# Out:
# [('OLEANDER CLUE', Decimal('0.99')),
#  ('BUTCH PANTHER', Decimal('0.99')),
#  ('FURY MURDER', Decimal('0.99')),
#  ('GABLES METROPOLIS', Decimal('0.99')),
#  ('OKLAHOMA JUMANJI', Decimal('0.99')),
#  ('ODDS BOOGIE', Decimal('0.99')),
#  ('GANDHI KWAI', Decimal('0.99')),
#  ('BUTTERFLY CHOCOLAT', Decimal('0.99')),
#  ('NOVOCAINE FLIGHT', Decimal('0.99')),
#  ('CABIN FLASH', Decimal('0.99')),
#  ('GATHERING CALENDAR', Decimal('0.99')),
#  ('CADDYSHACK JEDI', Decimal('0.99')),
#  ('NOTTING SPEAKEASY', Decimal('0.99')),
#  ('GHOSTBUSTERS ELF', Decimal('0.99')),
#  ('TOOTSIE PILOT', Decimal('0.99')),
#  ('GILBERT PELICAN', Decimal('0.99')),
#  ('GILMORE BOILED', Decimal('0.99')),
#  ('NOTORIOUS REUNION', Decimal('0.99')),
#  ('GLASS DYING', Decimal('0.99')),
#  ('TOMATOES HELLFIGHTERS', Decimal('0.99')),
#  ('CAMELOT VACATION', Decimal('0.99')),
#  ('GO PURPLE', Decimal('0.99')),
#  ('ARSENIC INDEPENDENCE', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', Decimal('0.99')),
# ...

# %%
# по убыванию
connection.execute("""SELECT title, rental_rate FROM film
ORDER BY rental_rate DESC;
""").fetchall()
# Out:
# [('WASH HEAVENLY', Decimal('4.99')),
#  ('FRISCO FORREST', Decimal('4.99')),
#  ('PREJUDICE OLEANDER', Decimal('4.99')),
#  ('FRONTIER CABIN', Decimal('4.99')),
#  ('POSEIDON FOREVER', Decimal('4.99')),
#  ('FUGITIVE MAGUIRE', Decimal('4.99')),
#  ('WAR NOTTING', Decimal('4.99')),
#  ('PLUTO OLEANDER', Decimal('4.99')),
#  ('PLATOON INSTINCT', Decimal('4.99')),
#  ('GALAXY SWEETHEARTS', Decimal('4.99')),
#  ('GAMES BOWFINGER', Decimal('4.99')),
#  ('PITY BOUND', Decimal('4.99')),
#  ('TRAP GUYS', Decimal('4.99')),
#  ('GARDEN ISLAND', Decimal('4.99')),
#  ('TRAINSPOTTING STRANGERS', Decimal('4.99')),
#  ('PITTSBURGH HUNCHBACK', Decimal('4.99')),
#  ('TRAIN BUNCH', Decimal('4.99')),
#  ('GHOST GROUNDHOG', Decimal('4.99')),
#  ('PINOCCHIO SIMON', Decimal('4.99')),
#  ('TRAFFIC HOBBIT', Decimal('4.99')),
#  ('PHILADELPHIA WIFE', Decimal('4.99')),
#  ('PERDITION FARGO', Decimal('4.99')),
#  ('GLADIATOR WESTWARD', Decimal('4.99')),
#  ('PELICAN COMFORTS', Decimal('4.99')),
# ...

# %%
# сортируем по нескольким столбцам: продолжительности и цене проката
connection.execute("""SELECT title, length, rental_rate FROM film
ORDER BY length DESC, rental_rate DESC;
""").fetchall()
# Out:
# [('DARN FORRESTER', 185, Decimal('4.99')),
#  ('SOLDIERS EVOLUTION', 185, Decimal('4.99')),
#  ('CONTROL ANTHEM', 185, Decimal('4.99')),
#  ('HOME PITY', 185, Decimal('4.99')),
#  ('CHICAGO NORTH', 185, Decimal('4.99')),
#  ('MUSCLE BRIGHT', 185, Decimal('2.99')),
#  ('GANGS PRIDE', 185, Decimal('2.99')),
#  ('SWEET BROTHERHOOD', 185, Decimal('2.99')),
#  ('POND SEATTLE', 185, Decimal('2.99')),
#  ('WORST BANGER', 185, Decimal('2.99')),
#  ('MOONWALKER FOOL', 184, Decimal('4.99')),
#  ('KING EVOLUTION', 184, Decimal('4.99')),
#  ('CRYSTAL BREAKING', 184, Decimal('2.99')),
#  ('SONS INTERVIEW', 184, Decimal('2.99')),
#  ('CONSPIRACY SPIRIT', 184, Decimal('2.99')),
#  ('THEORY MERMAID', 184, Decimal('0.99')),
#  ('SMOOCHY CONTROL', 184, Decimal('0.99')),
#  ('SORORITY QUEEN', 184, Decimal('0.99')),
#  ('FRONTIER CABIN', 183, Decimal('4.99')),
#  ('WIFE TURN', 183, Decimal('4.99')),
#  ('SCALAWAG DUCK', 183, Decimal('4.99')),
#  ('CATCH AMISTAD', 183, Decimal('0.99')),
# ...

# %%
# найдем ID, имена, фамилии актеров, чья фамилия содержит LI, отсортируем в алфавитном порядке по фамилии, затем по имени
connection.execute("""SELECT actor_id, first_name, last_name FROM actor 
WHERE last_name LIKE '%%LI%%' 
ORDER BY last_name, first_name;
""").fetchmany(10)
# Out:
# [(86, 'GREG', 'CHAPLIN'),
#  (82, 'WOODY', 'JOLIE'),
#  (34, 'AUDREY', 'OLIVIER'),
#  (15, 'CUBA', 'OLIVIER'),
#  (172, 'GROUCHO', 'WILLIAMS'),
#  (137, 'MORGAN', 'WILLIAMS'),
#  (72, 'SEAN', 'WILLIAMS'),
#  (83, 'BEN', 'WILLIS'),
#  (96, 'GENE', 'WILLIS'),
#  (164, 'HUMPHREY', 'WILLIS')]

# %% [markdown]
# LIMIT

# %%
# Выведем первые 15 записей
connection.execute("""SELECT title, length, rental_rate FROM film
WHERE rental_rate > 2.99
ORDER BY length DESC, rental_rate
LIMIT 15;
""").fetchall()
# Out:
# [('SOLDIERS EVOLUTION', 185, Decimal('4.99')),
#  ('CONTROL ANTHEM', 185, Decimal('4.99')),
#  ('HOME PITY', 185, Decimal('4.99')),
#  ('DARN FORRESTER', 185, Decimal('4.99')),
#  ('CHICAGO NORTH', 185, Decimal('4.99')),
#  ('MOONWALKER FOOL', 184, Decimal('4.99')),
#  ('KING EVOLUTION', 184, Decimal('4.99')),
#  ('WIFE TURN', 183, Decimal('4.99')),
#  ('SCALAWAG DUCK', 183, Decimal('4.99')),
#  ('FRONTIER CABIN', 183, Decimal('4.99')),
#  ('SATURN NAME', 182, Decimal('4.99')),
#  ('MONSOON CAUSE', 182, Decimal('4.99')),
#  ('RECORDS ZORRO', 182, Decimal('4.99')),
#  ('REDS POCUS', 182, Decimal('4.99')),
#  ('HOTEL HAPPINESS', 181, Decimal('4.99'))]

# %% [markdown]
# INSERT/DELETE/UPDATE

# %%
#  insert delete update
connection.execute("""SELECT * FROM rental;
""").fetchmany(10)
# Out:
# [(2, datetime.datetime(2005, 5, 24, 22, 54, 33, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1525, 459, datetime.datetime(2005, 5, 28, 19, 40, 33, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1, datetime.datetime(2017, 2, 16, 2, 30, 53, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (3, datetime.datetime(2005, 5, 24, 23, 3, 39, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1711, 408, datetime.datetime(2005, 6, 1, 22, 12, 39, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1, datetime.datetime(2017, 2, 16, 2, 30, 53, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
# ...

# %%
# INSERT. добавим новый прокат
connection.execute("""INSERT INTO rental(rental_date, inventory_id, customer_id, staff_id) 
           VALUES(NOW(), 1, 3, 2);
""")

# %%
# пример с нарушением внешнего ключа
# connection.execute("""INSERT INTO rental(rental_date, inventory_id, customer_id, staff_id) 
#            VALUES(NOW(), 1, 3, 3);
# """)
# Out:
# ---------------------------------------------------------------------------
# ForeignKeyViolation                       Traceback (most recent call last)
# C:\Programs\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1277                     self.dialect.do_execute(
# -> 1278                         cursor, statement, parameters, context
#    1279                     )
#
# C:\Programs\Anaconda\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# ForeignKeyViolation: ОШИБКА:  INSERT или UPDATE в таблице "rental" нарушает ограничение внешнего ключа "rental_staff_id_fkey"
# DETAIL:  Ключ (staff_id)=(3) отсутствует в таблице "staff".
#
#
# ...

# %%
# проверим
connection.execute("""SELECT * FROM rental
WHERE staff_id = 2 and inventory_id = 1;
""").fetchall()
# Out:
# [(4863, datetime.datetime(2005, 7, 8, 19, 3, 15, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1, 431, datetime.datetime(2005, 7, 11, 21, 29, 15, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 2, datetime.datetime(2017, 2, 16, 2, 30, 53, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16057, datetime.datetime(2020, 8, 6, 17, 11, 24, 622860, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1, 3, None, 2, datetime.datetime(2020, 8, 6, 17, 11, 24, 622860, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16059, datetime.datetime(2020, 9, 25, 16, 37, 35, 498865, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1, 3, None, 2, datetime.datetime(2020, 9, 25, 16, 37, 35, 498865, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)))]

# %%
# UPDATE. добавим возврат из проката
connection.execute("""UPDATE rental
           SET return_date = NOW()
           WHERE rental_id = 16059;
""")

# %%
# проверим
connection.execute("""SELECT * FROM rental
WHERE staff_id = 2 and inventory_id = 1;
""").fetchall()
# Out:
# [(4863, datetime.datetime(2005, 7, 8, 19, 3, 15, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1, 431, datetime.datetime(2005, 7, 11, 21, 29, 15, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 2, datetime.datetime(2017, 2, 16, 2, 30, 53, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16057, datetime.datetime(2020, 8, 6, 17, 11, 24, 622860, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1, 3, None, 2, datetime.datetime(2020, 8, 6, 17, 11, 24, 622860, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16059, datetime.datetime(2020, 9, 25, 16, 37, 35, 498865, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1, 3, datetime.datetime(2020, 9, 25, 17, 5, 18, 56205, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 2, datetime.datetime(2020, 9, 25, 17, 5, 18, 56205, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)))]

# %%
# insert можно кобминировать с Select, чтобы копировать данные из одной таблицы в другую
# INSERT INTO table2
# SELECT * FROM table1
# WHERE condition;

# %%
# DELETE
connection.execute("""DELETE FROM rental
           WHERE rental_id = 16059
""")

# %%
# проверим
connection.execute("""SELECT * FROM rental
WHERE rental_id = 16059;
""").fetchall()
# Out:
# []
